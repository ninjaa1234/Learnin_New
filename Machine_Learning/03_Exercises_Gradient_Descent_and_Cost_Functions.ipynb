# %% [markdown]
# <a href="https://colab.research.google.com/github/ninjaa1234/Learning_New/blob/main/Machine_Learning/03_Exercises_Gradient_Descent_and_Cost_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import math
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/3_gradient_descent/Exercise/test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
reg = LinearRegression()
reg.fit(df[['math']],df.cs)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([1.01773624])

# %%
reg.intercept_
# Out:
# 1.9152193111569034

# %%
def gradient_descent(x,y):
    m_curr =0
    b_curr=0
    iterations = 1000000
    n = len(x)
    learning_rate = 0.0002

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        #cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        cost = (1/n) * sum((y-y_predicted)**2)
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
    

x=np.array(df.math)
y=np.array(df.cs)

gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 1.0177362378601513, b 1.9152193109288085, cost 31.604511333529576 iteration 995000
# m 1.017736237860151, b 1.9152193109288138, cost 31.604511333529572 iteration 995001
# m 1.0177362378601509, b 1.9152193109288191, cost 31.604511333529583 iteration 995002
# m 1.017736237860151, b 1.9152193109288245, cost 31.604511333529594 iteration 995003
# m 1.0177362378601509, b 1.9152193109288298, cost 31.604511333529583 iteration 995004
# m 1.0177362378601509, b 1.9152193109288351, cost 31.604511333529583 iteration 995005
# m 1.0177362378601509, b 1.9152193109288405, cost 31.604511333529587 iteration 995006
# m 1.0177362378601507, b 1.9152193109288458, cost 31.604511333529622 iteration 995007
# m 1.0177362378601507, b 1.9152193109288511, cost 31.604511333529572 iteration 995008
# m 1.0177362378601507, b 1.9152193109288564, cost 31.604511333529572 iteration 995009
# ...
