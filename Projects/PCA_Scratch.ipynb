# %% [markdown]
# <a href="https://colab.research.google.com/github/ninjaa1234/Learning_New/blob/main/Projects/PCA_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  import numpy as np

# %% [markdown]
# #generate some data

# %%
X = np.random.normal(0, 1, (100, 4))

# %%
X
# Out:
# array([[ 8.90208807e-01, -6.62880243e-02,  2.68572744e-01,
#         -3.18705468e-01],
#        [ 1.30657576e+00, -1.55893247e-01,  7.73806291e-01,
#          1.18792198e+00],
#        [-6.67051406e-02, -2.09733211e+00, -4.77443745e-01,
#         -1.30245262e+00],
#        [-2.00864053e+00, -4.87328270e-01, -1.03265409e+00,
#         -2.14107150e-01],
#        [-6.42855756e-01,  6.14392978e-01,  3.55386118e-01,
#         -4.71404708e-02],
#        [-9.93457846e-01,  4.87927078e-01,  1.65451035e+00,
#          9.15406243e-01],
#        [ 1.58156528e-01,  1.63476142e+00,  1.48606135e+00,
#          1.14971665e+00],
#        [ 1.00241970e+00, -9.41559528e-01,  7.99960373e-01,
#         -4.67496706e-01],
#        [-1.30146133e+00,  2.87687082e+00, -1.19457454e+00,
#          1.32977356e+00],
#        [ 9.19856895e-02, -1.68313256e-01, -1.52797274e-01,
#         -4.04492341e-02],
#        [ 1.12338943e+00, -1.07516082e+00, -1.43702281e+00,
#          1.06720589e-01],
# ...

# %% [markdown]
# #compute covariance matrix

# %%
cov_matrix = sum([X[i].reshape(-1,1) @ X[i].reshape(1,-1) for i in range(100)]) / 100

# %% [markdown]
# #eigenvalues and eigenvectors of covariance matrix

# %%
eigvecs = np.linalg.eig(cov_matrix)

# %% [markdown]
# #pca

# %%
pca= eigvecs[1]

# %%
pca
# Out:
# array([[-0.83444522, -0.13355238, -0.53241551,  0.04897614],
#        [-0.22775446,  0.8954865 ,  0.09833575, -0.36954283],
#        [ 0.46203427,  0.02046558, -0.7697462 , -0.43999578],
#        [ 0.19584027,  0.42408589, -0.33816357,  0.81697194]])
